# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesitexp/DataScience_Zone/blob/main/Linear_Regression_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as mp

# %%
from google.colab import files
raw_data=files.upload()
# Out:
#      <input type="file" id="files-0b6d3363-35e7-4be4-a792-f6b18d4ed968" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b6d3363-35e7-4be4-a792-f6b18d4ed968">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('01Students.csv')

# %%
df
# Out:
#     Hours  Marks
# 0       0     34
# 1       1     36
# 2       1     33
# 3       1     39
# 4       1     42
# 5       2     45
# 6       2     38
# 7       3     45
# 8       3     53
# 9       3     46
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88
# 20      7     61
# 21      7     74
# 22      8     71
# 23      8     89
# 24      9     82
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %% [markdown]
# #EDA

# %%
df.head()
# Out:
#    Hours  Marks
# 0      0     34
# 1      1     36
# 2      1     33
# 3      1     39
# 4      1     42

# %%
df.tail()
# Out:
#     Hours  Marks
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %%
df.iloc[15:20]
# Out:
#     Hours  Marks
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88

# %%
df.describe()
# Out:
#            Hours      Marks
# count  30.000000  30.000000
# mean    5.200000  61.400000
# std     3.188341  17.734828
# min     0.000000  33.000000
# 25%     3.000000  45.250000
# 50%     5.000000  60.000000
# 75%     7.750000  77.000000
# max    11.000000  89.000000

# %% [markdown]
# Data cleaning

# %%
df.isnull().sum()
# Out:
# Hours    0
# Marks    0
# dtype: int64

# %% [markdown]
# Label encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   30 non-null     int64
#  1   Marks   30 non-null     int64
# dtypes: int64(2)
# memory usage: 612.0 bytes

# %% [markdown]
# #x,y *split*

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#     Hours
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
# 5       2
# 6       2
# 7       3
# 8       3
# 9       3
# 10      3
# 11      4
# 12      4
# 13      4
# 14      5
# 15      5
# 16      6
# 17      6
# 18      7
# 19      7
# 20      7
# 21      7
# 22      8
# 23      8
# 24      9
# 25      9
# 26      9
# 27     10
# 28     10
# 29     11

# %%
y
# Out:
# 0     34
# 1     36
# 2     33
# 3     39
# 4     42
# 5     45
# 6     38
# 7     45
# 8     53
# 9     46
# 10    56
# 11    59
# 12    55
# 13    56
# 14    72
# 15    59
# 16    62
# 17    71
# 18    78
# 19    88
# 20    61
# 21    74
# 22    71
# 23    89
# 24    82
# 25    67
# 26    89
# 27    81
# 28    82
# 29    79
# Name: Marks, dtype: int64

# %% [markdown]
# #Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (24, 1)

# %%
x_test.shape
# Out:
# (6, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([84.85949596, 59.91714709, 74.88255642, 64.90561687, 49.94020754,
#        49.94020754])

# %%
y_test
# Out:
# 27    81
# 15    59
# 23    89
# 17    71
# 8     53
# 9     46
# Name: Marks, dtype: int64

# %%
error=y_predict-y_test

# %%
error
# Out:
# 27     3.859496
# 15     0.917147
# 23   -14.117444
# 17    -6.094383
# 8     -3.059792
# 9      3.940208
# Name: Marks, dtype: float64

# %% [markdown]
# #Land SQRT_PRICE

# %%
from google.colab import files
raw_data=files.upload()
# Out:
#      <input type="file" id="files-e848c0b0-27bd-45db-8100-047e40246209" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e848c0b0-27bd-45db-8100-047e40246209">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('square_feet_price_dataset.csv')

# %%
df
# Out:
#     sqr_ft   price
# 0      702  140400
# 1      948  189600
# 2      870  174000
# 3      706  141200
# 4      671  134200
# 5      788  157600
# 6      620  124000
# 7      702  140400
# 8      721  144200
# 9      814  162800
# 10     930  186000
# 11     687  137400
# 12     972  194400
# 13     699  139800
# 14     959  191800
# 15     751  150200
# 16     730  146000
# 17     749  149800
# 18     908  181600
# 19     857  171400
# 20     943  188600
# 21     893  178600
# 22     985  197000
# 23     791  158200
# 24     876  175200
# 25     760  152000
# 26     913  182600
# 27     621  124200
# 28     852  170400
# 29     835  167000
# 30     944  188800
# 31     648  129600
# 32     658  131600
# 33     769  153800
# 34     787  157400
# 35     870  174000
# 36     789  157800
# 37     774  154800
# 38     650  130000
# 39     963  192600
# 40     654  130800
# 41     843  168600
# 42     919  183800
# 43     730  146000
# 44     906  181200
# 45     734  146800
# ...

# %%
df.head()
# Out:
#    sqr_ft   price
# 0     702  140400
# 1     948  189600
# 2     870  174000
# 3     706  141200
# 4     671  134200

# %%
df.tail()
# Out:
#     sqr_ft   price
# 45     734  146800
# 46     620  124000
# 47     928  185600
# 48     766  153200
# 49     873  174600

# %%
df.iloc[20:30]
# Out:
#     sqr_ft   price
# 20     943  188600
# 21     893  178600
# 22     985  197000
# 23     791  158200
# 24     876  175200
# 25     760  152000
# 26     913  182600
# 27     621  124200
# 28     852  170400
# 29     835  167000

# %%
df.describe()
# Out:
#            sqr_ft          price
# count   50.000000      50.000000
# mean   801.560000  160312.000000
# std    109.022027   21804.405471
# min    620.000000  124000.000000
# 25%    709.750000  141950.000000
# 50%    788.500000  157700.000000
# 75%    902.750000  180550.000000
# max    985.000000  197000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sqr_ft  50 non-null     int64
#  1   price   50 non-null     int64
# dtypes: int64(2)
# memory usage: 932.0 bytes

# %% [markdown]
# #x,y *split*

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#     sqr_ft
# 0      702
# 1      948
# 2      870
# 3      706
# 4      671
# 5      788
# 6      620
# 7      702
# 8      721
# 9      814
# 10     930
# 11     687
# 12     972
# 13     699
# 14     959
# 15     751
# 16     730
# 17     749
# 18     908
# 19     857
# 20     943
# 21     893
# 22     985
# 23     791
# 24     876
# 25     760
# 26     913
# 27     621
# 28     852
# 29     835
# 30     944
# 31     648
# 32     658
# 33     769
# 34     787
# 35     870
# 36     789
# 37     774
# 38     650
# 39     963
# 40     654
# 41     843
# 42     919
# 43     730
# 44     906
# 45     734
# 46     620
# 47     928
# 48     766
# 49     873

# %%
y
# Out:
# 0     140400
# 1     189600
# 2     174000
# 3     141200
# 4     134200
# 5     157600
# 6     124000
# 7     140400
# 8     144200
# 9     162800
# 10    186000
# 11    137400
# 12    194400
# 13    139800
# 14    191800
# 15    150200
# 16    146000
# 17    149800
# 18    181600
# 19    171400
# 20    188600
# 21    178600
# 22    197000
# 23    158200
# 24    175200
# 25    152000
# 26    182600
# 27    124200
# 28    170400
# 29    167000
# 30    188800
# 31    129600
# 32    131600
# 33    153800
# 34    157400
# 35    174000
# 36    157800
# 37    154800
# 38    130000
# 39    192600
# 40    130800
# 41    168600
# 42    183800
# 43    146000
# 44    181200
# 45    146800
# 46    124000
# 47    185600
# 48    153200
# 49    174600
# Name: price, dtype: int64

# %% [markdown]
# #Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=92)

# %%
x_train.shape
# Out:
# (37, 1)

# %%
x_test.shape
# Out:
# (13, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([152000., 153200., 124000., 144200., 146000., 178600., 154800.,
#        171400., 174000., 157600., 157800., 158200., 140400.])

# %%
y_test
# Out:
# 25    152000
# 48    153200
# 46    124000
# 8     144200
# 16    146000
# 21    178600
# 37    154800
# 19    171400
# 2     174000
# 5     157600
# 36    157800
# 23    158200
# 7     140400
# Name: price, dtype: int64

# %%
error=y_predict-y_test

# %%
error
# Out:
# 25    0.000000e+00
# 48    0.000000e+00
# 46    0.000000e+00
# 8     0.000000e+00
# 16    0.000000e+00
# 21   -2.910383e-11
# 37    0.000000e+00
# 19   -2.910383e-11
# 2    -2.910383e-11
# 5     0.000000e+00
# 36    0.000000e+00
# 23    0.000000e+00
# 7     0.000000e+00
# Name: price, dtype: float64
