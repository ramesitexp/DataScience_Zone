# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesitexp/DataScience_Zone/blob/main/nlp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
# !pip install nltk

# %% [markdown]
# text input -- nltk -- text preprocessing -- data frame -- x, y --- train test -- ML model --- evaluation

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# datapreprocessing

# %%
from nltk.tokenize import word_tokenize

# %%
text = " this is the first session in NLP. am a beginner data scientist"

# %%
nltk.download('punkt_tab')
print(word_tokenize(text))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# ['this', 'is', 'the', 'first', 'session', 'in', 'NLP', '.', 'am', 'a', 'beginner', 'data', 'scientist']
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.tokenize import sent_tokenize

# %%
print(sent_tokenize(text))
# Out:
# [' this is the first session in NLP.', 'am a beginner data scientist']

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
tokenizer = WhitespaceTokenizer()
print(tokenizer.tokenize(text))
# Out:
# ['this', 'is', 'the', 'first', 'session', 'in', 'NLP.', 'am', 'a', 'beginner', 'data', 'scientist']

# %%
from nltk.tokenize import RegexpTokenizer

# %%
print(RegexpTokenizer(text))
# Out:
# RegexpTokenizer(pattern=' this is the first session in NLP. am a beginner data scientist', gaps=False, discard_empty=True, flags=re.UNICODE|re.MULTILINE|re.DOTALL)

# %%
import re

# %% [markdown]
# !@#$%^&*(),<>,?/

# %%
re.findall(r'\w+',"hi ### india*/#")
# Out:
# ['hi', 'india']

# %%
# !pip install tamil_tokenizer

# %%
from tamil_tokenizer import TamilTokenizer

# %%
text_2 = "திருக்குறள் (Tirukkural), சுருக்கமாக குறள் (Kural), ஒரு தொன்மையான தமிழ் மொழி அற இலக்கியமாகும். சங்க இலக்கிய வகைப்பாட்டில் பதினெண்கீழ்க்கணக்கு எனப்படும் பதினெட்டு நூல்களின் திரட்டில் இருக்கும் இந்நூல் குறள் வெண்பா என்னும் பாவகையினாலான 1,330 ஈரடிச் செய்யுள்களைக் கொண்டது.[1] இந்நூல் முறையே அறம், பொருள், இன்பம் ஆகிய மூன்று தொகுப்புகளைக் கொண்டது "

# %%
tokenizer = TamilTokenizer()
print(tokenizer.tokenize(text_2))
# Out:
# ['திருக்குறள்', 'சுருக்கமாக', 'குறள்', 'ஒரு', 'தொன்மையான', 'தமிழ்', 'மொழி', 'அற', 'இலக்கியமாகும்', 'சங்க', 'இலக்கிய', 'வகைப்பாட்டில்', 'பதினெண்கீழ்க்கணக்கு', 'எனப்படும்', 'பதினெட்டு', 'நூல்களின்', 'திரட்டில்', 'இருக்கும்', 'இந்நூல்', 'குறள்', 'வெண்பா', 'என்னும்', 'பாவகையினாலான', 'ஈரடிச்', 'செய்யுள்களைக்', 'கொண்டது', 'இந்நூல்', 'முறையே', 'அறம்', 'பொருள்', 'இன்பம்', 'ஆகிய', 'மூன்று', 'தொகுப்புகளைக்', 'கொண்டது']
