# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesitexp/DataScience_Zone/blob/main/python_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t=(10,20,30,40,50)


val=list(map(lambda x:x**2,t))
print(val)
# Out:
# [100, 400, 900, 1600, 2500]

# %%
t=(10,20,30,40,50)

# %%
fil=list(filter(lambda x:(x%2==0),t))
print(fil)
# Out:
# [10, 20, 30, 40, 50]

# %%
from functools import reduce

# %%
t=(10,20,30,40,50)

red=reduce(lambda x,y:x+y,t)
red
# Out:
# 150

# %%
oe=lambda x:"odd" if x%2!=0 else "even"
oe(11)
# Out:
# 'odd'

# %%
# s=a^2+2b+c  #c=20


s=lambda a,b,c=20: (a**2)+(2*b)+c
s(11,12)
# Out:
# 165

# %%
# a,b


b=lambda x,y: "bigger" if x>y else "lower"
b(20,10)
# Out:
# 'bigger'

# %%
import math

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sin(30)
# Out:
# -0.9880316240928618

# %%
math.asin(0.56)
# Out:
# 0.5943858000010622

# %%
math.sqrt(8)
# Out:
# 2.8284271247461903

# %%
math.inf>1000000
# Out:
# True

# %%
math.factorial(9)
# Out:
# 362880

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
math.log10(80)
# Out:
# 1.9030899869919435

# %%
math.log2(567)
# Out:
# 9.147204924942228

# %%
math.ceil(9.6)
# Out:
# 10

# %%
math.floor(9.6)
# Out:
# 9

# %%
math.fabs(-70)
# Out:
# 70.0

# %%
math.floor(4.5)
# Out:
# 4

# %%
math.fmod(10,3)
# Out:
# 1.0

# %%
math.gcd(1,2,4)
# Out:
# 1

# %%
math.lcm(1,2,4)
# Out:
# 4

# %%
math.gamma(70)
# Out:
# 1.711224524281413e+98

# %%
t=('abc','b')

import array as ar
a1=ar.array('u',t)
print(a1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-886516140f26> in <cell line: 0>()
#       2
#       3 import array as ar
# ----> 4 a1=ar.array('u',t)
#       5 print(a1)
#
# TypeError: array item must be unicode character

# %%
t=(1,2,4567)

d={1:'a',2:'b',3:'c'}

import array as ar
a2=ar.array('i',d)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cd44f9199b52> in <cell line: 0>()
#       5 import array as ar
#       6 a2=ar.array('i',d)
# ----> 7 print(a)
#
# NameError: name 'a' is not defined

# %%
# from os import *

# from os import * or import os

from os import fspath as fs

# %%
from array import array



import array as ar

commentary = "Kohli hits the ball over mid-wicket for a magnificent six!"
char_array = array('u', commentary)

print(char_array.tolist())
# Out:
# ['K', 'o', 'h', 'l', 'i', ' ', 'h', 'i', 't', 's', ' ', 't', 'h', 'e', ' ', 'b', 'a', 'l', 'l', ' ', 'o', 'v', 'e', 'r', ' ', 'm', 'i', 'd', '-', 'w', 'i', 'c', 'k', 'e', 't', ' ', 'f', 'o', 'r', ' ', 'a', ' ', 'm', 'a', 'g', 'n', 'i', 'f', 'i', 'c', 'e', 'n', 't', ' ', 's', 'i', 'x', '!']

# %%
l=[]
for i in range(10000000):
    l.append(i)
for i in l:
    print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
#