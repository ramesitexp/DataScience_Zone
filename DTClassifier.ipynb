# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesitexp/DataScience_Zone/blob/main/DTClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedKFold
from sklearn.tree import DecisionTreeClassifier,export_text
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import joblib

# %%
RANDOM_STATE = 42

# %%
x,y = make_classification(n_samples=3000,n_features=12,n_informative=6,
                            n_redundant=2,n_repeated=0,n_classes=2,
                            n_clusters_per_class=2,weights=[0.5,0.3],
                            class_sep=1.0,random_state=RANDOM_STATE)

# %%
x
# Out:
# array([[-0.9832613 , -0.86772042, -0.69264023, ...,  1.6468856 ,
#         -3.23935183,  1.50871842],
#        [-0.75960547, -0.63930552,  1.42040092, ...,  1.58071045,
#         -0.95724211, -2.17213222],
#        [-2.35265674, -2.28975998, -0.02567526, ..., -0.81902766,
#         -0.13774353, -1.06466637],
#        ...,
#        [ 1.83292346, -0.92515279, -0.20208691, ...,  0.36328549,
#         -1.40211602,  1.39476019],
#        [-1.27006423, -0.63264456, -1.77982318, ...,  3.22644024,
#         -0.6787356 ,  0.16140991],
#        [-0.50870032,  0.55298392,  0.13315453, ...,  0.68239951,
#         -2.63432521, -1.59691496]])

# %%
feature_names = [
    "age", "income", "credit_score", "loan_amount", "tenure_months", "expenses",
    "savings", "debt_ratio", "late_payments", "dependents", "employment_years", "region_score"
]

# %%
df = pd.DataFrame(x, columns=feature_names)
df["label"] = y

# %%
df
# Out:
#            age    income  credit_score  loan_amount  tenure_months  expenses  \
# 0    -0.983261 -0.867720     -0.692640     2.306495      -1.210349 -1.201374
# 1    -0.759605 -0.639306      1.420401    -1.701708       0.996033  1.012635
# 2    -2.352657 -2.289760     -0.025675     0.798428      -1.499715 -1.277913
# 3    -2.325262  0.470677      0.814987     2.436224      -0.902198 -0.876935
# 4     0.370271  1.802761     -0.208493    -1.571248       0.893004 -0.330824
# ...        ...       ...           ...          ...            ...       ...
# 2995  0.299643  4.292498      1.221835     2.381440      -1.627002  0.727114
# 2996 -1.322178  1.295796     -1.110354    -2.935760       1.935914 -1.160373
# 2997  1.832923 -0.925153     -0.202087    -0.917535      -0.226334  0.347599
# 2998 -1.270064 -0.632645     -1.779823     2.091030      -0.732139  0.214352
# 2999 -0.508700  0.552984      0.133155     0.275973       0.620052  1.736324
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
)

# %%
DecisionTree = DecisionTreeClassifier(random_state=RANDOM_STATE,criterion='entropy')

# %%
DecisionTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
accuracy_train = accuracy_score(y_train, DecisionTree.predict(x_train))

# %%
accuracy_train
# Out:
# 1.0

# %%
print(classification_report(y_train, DecisionTree.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1439
#            1       1.00      1.00      1.00       961
#
#     accuracy                           1.00      2400
#    macro avg       1.00      1.00      1.00      2400
# weighted avg       1.00      1.00      1.00      2400

# %%
pip install graphviz

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
export_graphviz(DecisionTree, out_file="tree.dot",
                feature_names=feature_names, filled=True, rounded=True,
                class_names=["0", "1"])

# %%
from graphviz import Source

with open("tree.dot") as f:
    dot_graph = f.read()

graph = Source(dot_graph)
graph.format = "png"
graph.render("decision_tree")
# Out:
# 'decision_tree.png'
