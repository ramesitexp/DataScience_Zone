# %% [markdown]
# <a href="https://colab.research.google.com/github/ramesitexp/DataScience_Zone/blob/main/Continuous_LinearRegression_Day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
age = [[12],[17],[16],[8],[6],[6.8],[6.9],[25],[13],[13.7]]
std = [[6],[12],[11],[3],[1],[1],[1],[12],[7],[8]]

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
plt.xlabel('age')
plt.ylabel('std')
plt.plot(age,std,'*')

# %%
plt.xlabel('age')
plt.ylabel('std')
plt.plot(age,std,'*')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model=LinearRegression()

# %%
model.fit(age,std)
# Out:
# LinearRegression()

# %%
model.fit(age,std)
# Out:
# LinearRegression()

# %%
model.predict([[9]])
# Out:
# array([[3.7581734]])

# %%
model.predict([[0]])
# Out:
# array([[-2.63032643]])
